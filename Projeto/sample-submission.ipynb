# %%
import pandas as pd 

data = pd.read_csv("../input/ferramentas-avancadas-projeto/test_set.csv")

data.head()
# Out:
#                  track_id               artists                   album_name  \
# 0  6MxGvnJWqdGS0chQypGXhB  J Balvin;Ryan Castro  Feliz Cumpleaños con Perreo
# 1  1VKnVxZZnubjTEJG6Tme1y            Papa Dance                   Papa Dance
# 2  3Lu4WAsmpag6CZSN0H3Wor            Steely Dan          Fiesta temática 70s
# 3  64JF6DqxJsGxiyUAhbHX49               Ednardo                      Ednardo
# 4  3TjXPh8bOY0K6K5WnReqH8       Esteban Morgado                  Milongueros
#
#                 track_name  duration_ms  explicit  danceability  energy  key  \
# 0          Nivel De Perreo       151573      True         0.802   0.828    1
# 1          Kamikadze wróć!       220266     False         0.786   0.866   11
# 2              Do It Again       354933     False         0.695   0.583    2
# 3  Enquanto Engoma A Calça       213133     False         0.655   0.759    0
# 4                 Oblivion       305680     False         0.366   0.465    2
#
# ...

# %%
data = data.drop(['artists', 'album_name', 'track_name', 'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'track_genre'], axis=1)

data["popularity"] = 50.0

data.head()
# Out:
#                  track_id  popularity
# 0  6MxGvnJWqdGS0chQypGXhB        50.0
# 1  1VKnVxZZnubjTEJG6Tme1y        50.0
# 2  3Lu4WAsmpag6CZSN0H3Wor        50.0
# 3  64JF6DqxJsGxiyUAhbHX49        50.0
# 4  3TjXPh8bOY0K6K5WnReqH8        50.0

# %%
data.to_csv('submission.csv', index=False)
